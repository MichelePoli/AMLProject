# %% [markdown]
# ## Data of **3b**

# %%
import matplotlib.pyplot as plt
import numpy as np

# Dati delle epoche
epochs = list(range(1, 21))
loss_A1 = [1.1788, 1.0885, 1.0276, 0.9928, 0.9461, 0.9090, 0.8651, 0.8536, 0.8208, 0.8205, 
        0.7738, 0.7528, 0.7290, 0.6892, 0.6669, 0.6495, 0.6456, 0.5940, 0.5703, 0.5562]
mIoU_A1 = [0.0935, 0.0970, 0.1453, 0.1225, 0.1489, 0.1421, 0.1717, 0.1582, 0.1682, 0.1434, 
            0.1452, 0.1579, 0.1723, 0.1655, 0.1659, 0.2047, 0.1609, 0.1875, 0.2328, 0.2202]


loss_A1_A2 = [0.7638, 0.6347,  0.5844, 0.5844, 0.5578, 0.5172, 0.4701, 0.4315, 0.3975, 0.3762, 0.3537, 0.3338, 0.3334, 0.3007, 0.3819, 0.3405, 0.2734, 0.2516,0.2465, 0.2338]
mIoU_A1_A2 = [0.1425, 0.1797, 0.1814, 0.1699, 0.1998, 0.1567, 0.1784, 0.1771, 0.1532, 0.1617, 0.1734, 0.1684, 0.1746, 0.1649, 0.1755, 0.1637, 0.1730, 0.1798, 0.1716, 0.1643]


mIoU_A2 = [0.1948, 0.2009, 0.2112, 0.1913, 0.1755, 0.1835, 0.1623, 0.1996, 0.1929, 0.1952, 
        0.1879, 0.1845, 0.185, 0.1956, 0.1722, 0.1813, 0.2029, 0.2049, 0.1977, 0.1767]
loss_A2 = [0.5426, 0.5011, 0.4975, 0.4676, 0.4816, 0.4534, 0.4227, 0.409, 0.3872, 0.3807, 
        0.3785, 0.3538, 0.3417, 0.3254, 0.3312, 0.3673, 0.3072, 0.2966, 0.2937, 0.2991]


miou_base = [0.0932, 0.0645, 0.0695, 0.1315, 0.1070, 0.1163, 0.1085, 0.1237, 0.1080, 0.1349, 0.1214, 0.1211, 0.1307, 0.1386, 0.1184, 0.1545, 0.1642, 0.1574, 0.1644, 0.1272]
loss_values_base = [2.0319, 1.3278, 1.5070, 1.1888, 1.0426, 1.0174, 1.0038, 0.9711, 1.0097, 0.9600, 0.9246, 0.9199, 0.8807, 0.8457, 0.8697, 0.8645, 0.8150, 0.7782, 0.7608, 0.7388]


# IoU per classe (estratto dai tuoi dati)
per_class_iou_A1 = {
    "Background": [0.3733, 0.3237, 0.2622, 0.2935, 0.3323, 0.3308, 0.3615, 0.3818, 0.3393, 0.3801, 
                   0.3510, 0.3497, 0.4226, 0.3701, 0.4524, 0.4566, 0.3894, 0.3962, 0.4375, 0.4571],
    "Building": [0.1776, 0.1783, 0.2331, 0.1615, 0.1926, 0.2241, 0.2369, 0.2718, 0.2122, 0.1277, 
                 0.1461, 0.1655, 0.2050, 0.2103, 0.2148, 0.3187, 0.1909, 0.2255, 0.2799, 0.2866],
    "Road": [0.0213, 0.0099, 0.0175, 0.0423, 0.0594, 0.0750, 0.1379, 0.0799, 0.1637, 0.1797, 
             0.1270, 0.1177, 0.1314, 0.1605, 0.1238, 0.2228, 0.1945, 0.2171, 0.2616, 0.2255],
    "Water": [0.0430, 0.1310, 0.1769, 0.1929, 0.1848, 0.2477, 0.2227, 0.2525, 0.2194, 0.1407, 
              0.2565, 0.2561, 0.2056, 0.2531, 0.2473, 0.2554, 0.1842, 0.2562, 0.2595, 0.2699],
    "Barren": [0.0088, 0.0014, 0.1089, 0.0631, 0.0412, 0.0114, 0.0381, 0.0250, 0.0812, 0.0483, 
               0.0484, 0.0418, 0.0786, 0.0606, 0.0352, 0.0446, 0.0493, 0.0529, 0.0521, 0.0680],
    "Forest": [0.0303, 0.0336, 0.1315, 0.0637, 0.0366, 0.0823, 0.0551, 0.0592, 0.0667, 0.0253, 
               0.0715, 0.0662, 0.0227, 0.0552, 0.0178, 0.0524, 0.0095, 0.1111, 0.1026, 0.1008],
    "Agricultural": [0.0003, 0.0010, 0.0871, 0.0407, 0.1952, 0.0235, 0.1500, 0.0376, 0.0947, 0.1018, 
                     0.0162, 0.1086, 0.1404, 0.0487, 0.0700, 0.0826, 0.1085, 0.0532, 0.2363, 0.1338],
}

# Grafico della perdita
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss_A1, label='Training Loss A1', marker='o', color='blue')
plt.plot(epochs, loss_A1_A2, label='Training Loss A1 + A2', marker='o', color='green')
plt.plot(epochs, loss_A2, label='Training Loss A2', marker='o', color='red')
plt.plot(epochs, loss_values_base, label='Training Loss without aumentation', marker='o', color='orange')
plt.title('Training Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()
plt.show()

# Grafico del mIoU di validazione
plt.figure(figsize=(10, 6))
plt.plot(epochs, mIoU_A1, label='Validation mIoU A1', marker='s', color='blue')
plt.plot(epochs, mIoU_A1_A2, label='Validation mIoU A1 + A2', marker='s', color='green')
plt.plot(epochs, mIoU_A2, label='Validation mIoU A2', marker='s', color='red')
plt.plot(epochs, miou_base, label='Validation mIoU without aumentation', marker='s', color='orange')
plt.title('Validation mIoU Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('mIoU')
plt.grid(True)
plt.legend()
plt.show()

# Grafico dell'IoU per classe A1
plt.figure(figsize=(12, 8))
for class_name, iou_values in per_class_iou_A1.items():
    plt.plot(epochs, iou_values, label=class_name, marker=".")
plt.title('IoU Per Class Over Epochs A1')
plt.xlabel('Epochs')
plt.ylabel('IoU')
plt.grid(True)
plt.legend()
plt.show()



# IoU per classe per ogni epoca
epochs = list(range(1, 21))
class_names = ['Background', 'Building', 'Road', 'Water', 'Barren', 'Forest', 'Agricultural']
iou_values_A2 = {
    'Background': [0.433254, 0.425278, 0.464128, 0.407708, 0.373525, 0.385375, 0.350232, 0.397465, 0.415191, 0.427433, 0.404771, 0.404180, 0.410115, 0.436506, 0.420841, 0.376815, 0.438292, 0.403836, 0.408033, 0.432215],
    'Building': [0.233252, 0.254947, 0.245725, 0.258257, 0.180556, 0.193244, 0.168919, 0.224702, 0.229009, 0.215042, 0.224312, 0.209867, 0.231685, 0.245159, 0.196881, 0.257373, 0.272807, 0.263538, 0.241604, 0.194595],
    'Road': [0.198696, 0.234805, 0.241925, 0.232774, 0.189201, 0.229634, 0.212920, 0.190936, 0.161935, 0.205368, 0.215150, 0.197731, 0.190659, 0.199432, 0.209364, 0.206569, 0.217719, 0.236251, 0.228461, 0.205823],
    'Water': [0.249385, 0.268539, 0.288786, 0.258685, 0.257127, 0.263305, 0.236682, 0.276355, 0.255913, 0.291384, 0.259141, 0.265151, 0.266653, 0.232949, 0.230542, 0.241719, 0.271649, 0.268475, 0.258352, 0.221423],
    'Barren': [0.047463, 0.066079, 0.064817, 0.050069, 0.069297, 0.062313, 0.060738, 0.074648, 0.075642, 0.057457, 0.075425, 0.051273, 0.052383, 0.066489, 0.064194, 0.055039, 0.065567, 0.069581, 0.053006, 0.068918],
    'Forest': [0.053866, 0.077734, 0.069081, 0.072604, 0.029311, 0.091419, 0.073443, 0.099266, 0.087820, 0.069318, 0.080098, 0.052470, 0.086728, 0.092750, 0.041157, 0.097853, 0.067022, 0.127225, 0.112496, 0.051928],
    'Agricultural': [0.147669, 0.078686, 0.103706, 0.058972, 0.129814, 0.058986, 0.033280, 0.133604, 0.124514, 0.100496, 0.056217, 0.110497, 0.056595, 0.096018, 0.042630, 0.033846, 0.087343, 0.065398, 0.081863, 0.061696]
}

# Creazione del grafico
plt.figure(figsize=(12, 6))
for class_name in class_names:
    plt.plot(epochs, iou_values_A2[class_name], label=class_name, marker=".")

plt.title('IoU for Class Over Epochs A1 + A2')
plt.xlabel('Epoch')
plt.ylabel('IoU')
plt.ylim(0, 0.5)
plt.legend(title='Classi')
plt.grid(True)
plt.tight_layout()
plt.show()


iou_per_class_A1_A2 = {
    'Background': [0.4049, 0.3748, 0.3537, 0.3694, 0.4151, 0.3053, 0.3586, 0.3953, 0.3213, 0.3568, 0.4263, 0.3527, 0.3331, 0.3694, 0.3121, 0.3190, 0.3305, 0.3447, 0.3518, 0.3449],
    'Building': [0.2170, 0.2905, 0.2295, 0.2130, 0.2298, 0.2259, 0.2699, 0.2167, 0.1843, 0.1822, 0.2132, 0.1823, 0.2013, 0.1666, 0.2157, 0.1743, 0.2300, 0.1816, 0.1792, 0.1873],
    'Road': [0.1041, 0.2051, 0.1865, 0.1560, 0.2307, 0.1514, 0.1945, 0.2069, 0.1770, 0.2023, 0.1652, 0.2050, 0.2065, 0.1968, 0.2412, 0.2329, 0.2030, 0.2320, 0.2169, 0.2135],
    'Water': [0.1612, 0.1976, 0.2676, 0.2404, 0.2315, 0.2122, 0.2558, 0.2272, 0.2105, 0.2299, 0.2396, 0.2095, 0.2558, 0.2472, 0.2596, 0.2251, 0.2309, 0.2272, 0.2215, 0.2164],
    'Barren': [0.0584, 0.0528, 0.0466, 0.0529, 0.0651, 0.0544, 0.0547, 0.0682, 0.0437, 0.0691, 0.0709, 0.0706, 0.0709, 0.0688, 0.0571, 0.0861, 0.0600, 0.0735, 0.0678, 0.0624],
    'Forest': [0.0271, 0.0600, 0.0878, 0.0702, 0.0790, 0.0981, 0.0818, 0.0537, 0.0551, 0.0614, 0.0548, 0.0983, 0.1166, 0.0657, 0.1216, 0.0782, 0.1168, 0.0949, 0.1373, 0.0838],
    'Agricultural': [0.0248, 0.0771, 0.0979, 0.0877, 0.1475, 0.0494, 0.0337, 0.0716, 0.0804, 0.0300, 0.0442, 0.0602, 0.0382, 0.0400, 0.0209, 0.0442, 0.0398, 0.0723, 0.0264, 0.0415]
}





# Grafico IoU per classe
plt.figure(figsize=(12, 6))
for cls, iou_values in iou_per_class_A1_A2.items():
    plt.plot(epochs, iou_values, label=f"IoU - {cls}", marker=".")
plt.title("IoU per Class Over Epochs A2")
plt.xlabel("Epoch")
plt.ylabel("IoU")
plt.legend()
plt.grid(True)
plt.show()




#base
iou_per_class_base = {
    'Background': [0.422, 0.310, 0.381, 0.373, 0.355, 0.300, 0.377, 0.425, 0.416, 0.275, 0.417, 0.360, 0.397, 0.354, 0.137, 0.351, 0.394, 0.339, 0.461, 0.335],
    'Building': [0.086, 0.102, 0.080, 0.146, 0.172, 0.209, 0.128, 0.212, 0.120, 0.205, 0.161, 0.119, 0.187, 0.190, 0.272, 0.238, 0.267, 0.284, 0.242, 0.137],
    'Road': [0.0001, 0.0101, 0.0063, 0.0211, 0.0123, 0.0280, 0.0179, 0.0447, 0.0361, 0.0677, 0.0544, 0.0622, 0.0715, 0.0725, 0.0708, 0.1049, 0.1604, 0.1011, 0.1631, 0.1075],
    'Water': [0.126, 0.000, 0.0008, 0.0934, 0.0377, 0.1711, 0.2085, 0.1391, 0.1177, 0.1296, 0.1444, 0.2025, 0.1342, 0.1749, 0.2384, 0.1666, 0.2126, 0.2062, 0.1651, 0.2117],
    'Barren': [0.0156, 0.0281, 0.00002, 0.0590, 0.0012, 0.0181, 0.0087, 0.0326, 0.0354, 0.0973, 0.0396, 0.0268, 0.0683, 0.0911, 0.0175, 0.0787, 0.0750, 0.0575, 0.0588, 0.0528],
    'Forest': [0.0019, 0.00004, 0.0168, 0.0554, 0.0275, 0.0732, 0.0109, 0.0027, 0.0241, 0.0753, 0.0254, 0.0722, 0.0416, 0.0445, 0.0822, 0.0715, 0.0231, 0.1065, 0.0401, 0.0238],
    'Agricultural': [0.000002, 0.0, 0.0, 0.1710, 0.1414, 0.0131, 0.0076, 0.0081, 0.0055, 0.0935, 0.0068, 0.0042, 0.0145, 0.0418, 0.0093, 0.0699, 0.0169, 0.0073, 0.0185, 0.0213]
}


plt.figure(figsize=(12, 6))
for cls, iou_values in iou_per_class_base.items():
    plt.plot(epochs, iou_values, label=f"IoU - {cls}", marker=".")
plt.title("IoU per Class Over Epochs without aumentation")
plt.xlabel("Epoch")
plt.ylabel("IoU")
plt.legend()
plt.grid(True)
plt.show()
