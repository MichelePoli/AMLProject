# %% [markdown]
# ## Data of **3b** with aumentation **A1**

# %%
import matplotlib.pyplot as plt

# Dati raccolti durante l'allenamento
epochs = list(range(1, 21))  # Numero di epoche

# Mean Intersection over Union (mIoU)
miou = [0.1467, 0.1676, 0.1582, 0.2026, 0.1739, 0.1866, 0.2097, 0.2002, 0.2447, 0.2092, 
        0.2105, 0.2418, 0.2343, 0.1994, 0.1924, 0.2490, 0.2167, 0.2539, 0.2455, 0.2658]

# Per-class IoU
per_class_iou = {
    "Background": [0.3752, 0.4355, 0.3919, 0.4941, 0.4366, 0.4739, 0.4699, 0.4402, 0.4598, 0.5148,
                   0.4610, 0.5413, 0.5177, 0.4809, 0.4920, 0.4529, 0.4970, 0.5193, 0.5018, 0.4680],
    "Building": [0.1195, 0.2822, 0.2230, 0.2434, 0.1917, 0.2158, 0.2766, 0.2635, 0.2856, 0.2483,
                 0.3068, 0.2766, 0.3148, 0.2646, 0.2758, 0.3628, 0.2284, 0.3504, 0.2426, 0.3205],
    "Road": [0.1024, 0.1091, 0.1371, 0.1851, 0.1323, 0.1910, 0.2187, 0.1658, 0.2608, 0.1199,
             0.1124, 0.1643, 0.2078, 0.1679, 0.0944, 0.2151, 0.1796, 0.2350, 0.2165, 0.2273],
    "Water": [0.1406, 0.1673, 0.1376, 0.1325, 0.2021, 0.1694, 0.1644, 0.1944, 0.2502, 0.1643,
              0.1158, 0.2367, 0.1982, 0.2023, 0.1453, 0.2223, 0.2314, 0.2792, 0.2443, 0.2868],
    "Barren": [0.0585, 0.0323, 0.0579, 0.0635, 0.0516, 0.0644, 0.0325, 0.0823, 0.0617, 0.0411,
               0.0515, 0.1304, 0.0657, 0.0459, 0.0808, 0.0456, 0.0517, 0.0613, 0.0631, 0.0587],
    "Forest": [0.0976, 0.1011, 0.0972, 0.0378, 0.0719, 0.0213, 0.1208, 0.0734, 0.1416, 0.0394,
               0.0878, 0.0765, 0.0369, 0.0638, 0.0800, 0.1765, 0.1295, 0.0883, 0.2135, 0.1686],
    "Agricultural": [0.1330, 0.0453, 0.0620, 0.2617, 0.1308, 0.1702, 0.1846, 0.1813, 0.2527, 0.3361,
                     0.3378, 0.2664, 0.2986, 0.1700, 0.1779, 0.2676, 0.1991, 0.2432, 0.2361, 0.3306],
}

# Loss
loss = [2.31, 2.05, 1.89, 1.72, 1.58, 1.50, 1.42, 1.36, 1.29, 1.24,
        1.20, 1.15, 1.10, 1.06, 1.03, 1.00, 0.96, 0.93, 0.91, 0.89]

# Grafico mIoU
plt.figure(figsize=(12, 6))
plt.plot(epochs, miou, label='mIoU', marker='o', linestyle='-', color='b')
plt.title('Mean Intersection over Union (mIoU) per Epoch')
plt.xlabel('Epoch')
plt.ylabel('mIoU')
plt.legend()
plt.grid(True)
plt.show()

# Grafico IoU per classe
plt.figure(figsize=(12, 6))
for class_name, iou_values in per_class_iou.items():
    plt.plot(epochs, iou_values, label=class_name, marker='o', linestyle='-')

plt.title('Per-Class IoU per Epoch')
plt.xlabel('Epoch')
plt.ylabel('IoU')
plt.legend()
plt.grid(True)
plt.show()

# Grafico Loss
plt.figure(figsize=(12, 6))
plt.plot(epochs, loss, label='Loss', marker='o', linestyle='-', color='r')
plt.title('Training Loss per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()
