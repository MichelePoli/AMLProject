# %%
import matplotlib.pyplot as plt
import numpy as np

# Dati forniti
epochs = list(range(1, 21))
training_loss = [1.3576, 1.1771, 1.0730, 1.0237, 0.9859, 0.9971, 0.9375, 0.9026, 0.8777, 0.8930, 0.8654, 0.8504, 0.8207, 0.8116, 0.8082, 0.7886, 0.8005, 0.7739, 0.7763, 0.7756]
validation_loss = [1.5429, 1.5912, 3.6958, 1.5439, 1.4714, 1.1603, 1.7632, 1.6380, 2.1901, 1.7140, 1.2264, 1.2308, 1.5558, 1.9477, 1.2505, 3.0489, 1.5645, 1.4086, 1.9485, 1.6549]
validation_miou = [0.2320, 0.2194, 0.1177, 0.2761, 0.2910, 0.3128, 0.2802, 0.2898, 0.3078, 0.3166, 0.3329, 0.3149, 0.3082, 0.3095, 0.3415, 0.2937, 0.3247, 0.3375, 0.3043, 0.3590]

# Creazione dei grafici
plt.figure(figsize=(14, 14))

# Grafico Loss
plt.subplot(2, 1, 1)
plt.plot(epochs, training_loss, label='Training Loss', marker='o', color='blue')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='o', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid(True)

# Grafico mIoU
plt.subplot(2, 1, 2)
plt.plot(epochs, validation_miou, label='Validation mIoU', marker='o', color='green')
plt.xlabel('Epochs')
plt.ylabel('mIoU')
plt.title('Validation mIoU')
plt.legend()
plt.grid(True)

# Mostrare i grafici
plt.tight_layout()
plt.show()
