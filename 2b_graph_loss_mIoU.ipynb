# %% [markdown]
# ## Results of **STEP 2b**

# %%
import matplotlib.pyplot as plt
import numpy as np

# Dati forniti
epochs = list(range(1, 21))
training_loss_B2 = [1.3576, 1.1771, 1.0730, 1.0237, 0.9859, 0.9971, 0.9375, 0.9026, 0.8777, 0.8930, 0.8654, 0.8504, 0.8207, 0.8116, 0.8082, 0.7886, 0.8005, 0.7739, 0.7763, 0.7756]
validation_loss_B2 = [1.5429, 1.5912, 3.6958, 1.5439, 1.4714, 1.1603, 1.7632, 1.6380, 2.1901, 1.7140, 1.2264, 1.2308, 1.5558, 1.9477, 1.2505, 3.0489, 1.5645, 1.4086, 1.9485, 1.6549]
validation_miou_B2 = [0.2320, 0.2194, 0.1177, 0.2761, 0.2910, 0.3128, 0.2802, 0.2898, 0.3078, 0.3166, 0.3329, 0.3149, 0.3082, 0.3095, 0.3415, 0.2937, 0.3247, 0.3375, 0.3043, 0.3590]


training_loss_B16 = [1.1799, 0.8019, 0.7702, 0.7020, 0.6602, 0.6391, 0.6532, 0.6076, 0.6201, 0.5856, 0.5468, 0.5049, 0.4940, 0.4890, 0.4467, 0.4329, 0.4041, 0.4067, 0.3795, 0.3715]
validation_miou_B16 = [0.3476, 0.3886, 0.3769, 0.4348, 0.3997, 0.4169, 0.4514, 0.3939, 0.3970, 0.4179, 0.4285, 0.4867, 0.4539, 0.4300, 0.4172, 0.4255, 0.4545, 0.4429, 0.4486, 0.4517]

# Creazione dei grafici
plt.figure(figsize=(14, 14))

# Grafico Loss
plt.subplot(2, 1, 1)
plt.plot(epochs, training_loss_B2, label='Training Loss B2', marker='o', color='blue')
plt.plot(epochs, validation_loss_B2, label='Validation Loss B2', marker='o', color='orange')

plt.plot(epochs, training_loss_B16, label='Training Loss B16', marker='o', color='red')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid(True)

# Grafico mIoU
plt.subplot(2, 1, 2)
plt.plot(epochs, validation_miou_B2, label='Validation mIoU B2', marker='o', color='green')

plt.plot(epochs, validation_miou_B16, label='Validation mIoU B16', marker='o', color='red')


plt.xlabel('Epochs')
plt.ylabel('mIoU')
plt.title('Validation mIoU')
plt.legend()
plt.grid(True)

# Mostrare i grafici
plt.tight_layout()
plt.show()
