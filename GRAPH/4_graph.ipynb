# %%
import matplotlib.pyplot as plt
import numpy as np


train_loss = loss_values = [
    1.8081,  # Epoch 1
    1.0562,  # Epoch 2
    1.0013,  # Epoch 3
    0.9810,  # Epoch 4
    0.7993,  # Epoch 5
    0.9444,  # Epoch 6
    0.9812,  # Epoch 7
    0.8002,  # Epoch 8
    1.1242,  # Epoch 9
    0.8350,  # Epoch 10
    0.8367,  # Epoch 11
    0.8552,  # Epoch 12
    0.8672,  # Epoch 13
    0.8523,  # Epoch 14
    0.8795,  # Epoch 15
    0.8017,  # Epoch 16
    0.8496,  # Epoch 17
    0.8467,  # Epoch 18
    0.9231,  # Epoch 19
    0.7893   # Epoch 20
]

val_loss = [0.4801, 0.3500, 0.3102, 0.2756, 0.2508, 0.2304, 0.2153, 0.2027, 0.1910, 0.1815, 0.1730, 0.1652, 0.1585, 0.1525, 0.1471, 0.1424, 0.1382, 0.1343, 0.1308, 0.1276]
val_miou = [
    0.1246,  # Epoch 1
    0.2188,  # Epoch 2
    0.2631,  # Epoch 3
    0.2948,  # Epoch 4
    0.3063,  # Epoch 5
    0.2868,  # Epoch 6
    0.1819,  # Epoch 7
    0.1958,  # Epoch 8
    0.1419,  # Epoch 9
    0.1707,  # Epoch 10
    0.1734,  # Epoch 11
    0.1777,  # Epoch 12
    0.1847,  # Epoch 13
    0.2050,  # Epoch 14
    0.1967,  # Epoch 15
    0.1846,  # Epoch 16
    0.1768,  # Epoch 17
    0.1636,  # Epoch 18
    0.2015,  # Epoch 19
    0.1855   # Epoch 20
]


# Plot Training Loss
plt.figure(figsize=(12, 6))
plt.plot(range(1, 21), train_loss, marker='o', label='Training Loss 4b B16', color='orange')

plt.title('Training Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()
plt.show()


plt.figure(figsize=(12, 6))
plt.plot(range(1, 21), val_miou, marker='o', label='Validation mIoU 4b B16', color='orange')
plt.title('Validation mIoU Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('mIoU')
plt.grid(True)
plt.legend()
plt.show()
