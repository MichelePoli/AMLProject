# %%
import matplotlib.pyplot as plt
import numpy as np

# Dati (estratti dal log fornito)
epochs = np.arange(1, 21)
train_loss_B4 =[1.1091, 0.9136, 0.8146, 0.7552, 0.7332, 0.6734, 0.6221, 0.5988, 0.5389, 0.4960, 0.4711, 0.4646, 0.4798, 0.5750, 0.4619, 0.4179, 0.4015, 0.3974, 0.3930, 0.3887]
miou_B4 = [0.2983, 0.2925, 0.2972, 0.2907, 0.3262, 0.2992, 0.2825, 0.2986, 0.3301, 0.3177, 0.3265, 0.3023, 0.2771, 0.3115, 0.3379, 0.3227, 0.3140, 0.3285, 0.3229, 0.3218]
val_loss_B4 =[1.0445, 1.1196, 1.1494, 1.0364, 0.9608, 1.0882, 0.9884, 1.2051, 1.0816, 1.0904, 1.1218, 1.3987, 1.1696, 1.1413, 1.1382, 1.2826, 1.2293, 1.2871, 1.2861, 1.3463]
final_iou_B4 = [0.45379692, 0.31175447, 0.08664531, 0.4612361, 0.10841636, 0.25179467, 0.5689296]


# val_loss_B16 = [1.0063, 1.0645, 0.9353, 1.0049, 1.0600, 0.9958, 1.1007, 1.0335, 1.0418, 1.0574, 1.1253, 1.1290, 1.1881, 1.1773, 1.2656, 1.2576, 1.3884, 1.2242, 1.2497, 1.2985]
# train_loss_B16 = [1.0105, 0.7945, 0.7436, 0.6799, 0.6367, 0.5906, 0.5488, 0.5075, 0.4814, 0.4659, 0.4751, 0.4529, 0.4332, 0.4205, 0.4102, 0.4085, 0.4029, 0.4102, 0.4012, 0.3892]
# miou_B16 = [0.2880, 0.3029, 0.3355, 0.3141, 0.3285, 0.3313, 0.3290, 0.3277, 0.3231, 0.3456, 0.3313, 0.3264, 0.3364, 0.3350, 0.3434, 0.3466, 0.3489, 0.3352, 0.3521, 0.3440]

final_iou_B16 = [0.48789158, 0.24997048, 0.08104881, 0.5117013, 0.0984676, 0.23262875, 0.5907285]



train_loss_B16 = [1.2233, 0.9814, 0.9013, 0.8617, 0.7999, 0.7505, 0.6959, 0.6585, 0.6336, 0.7120, 0.6399, 0.6030, 0.5838, 0.5689, 0.5578, 0.5497, 0.5401, 0.5330, 0.5298, 0.5288]
val_loss_B16 = [1.4183, 1.9533, 1.3831, 1.6297, 1.5885, 1.7788, 1.6982, 1.8371, 2.0724, 1.8751, 1.9946, 1.8747, 1.9030, 1.9163, 1.7900, 1.9878, 1.8907, 2.0196, 1.8347, 1.9441]
miou_B16 = [0.2645, 0.1924, 0.3238, 0.2917, 0.3256, 0.2862, 0.3131, 0.3003, 0.3034, 0.3029, 0.2788, 0.3100, 0.3253, 0.3212, 0.3324, 0.3205, 0.3312, 0.3124, 0.3369, 0.3342]


# Grafico della perdita
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)

plt.plot(epochs, train_loss_B4, label='Train Loss B4', color='blue', marker='o')
plt.plot(epochs, train_loss_B16, label='Train Loss B16', color='red', marker='o')

# plt.plot(epochs, val_loss_B4, label='Validation Loss B4', color='green', marker='o')
# plt.plot(epochs, val_loss_B16, label='Validation Loss B16', color='orange', marker='o')


plt.title('Training Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

# Grafico mIoU
plt.subplot(1, 2, 2)

plt.plot(epochs, miou_B4, label='Validation mIoU B4', color='blue', marker='o')

plt.plot(epochs, miou_B16, label='Validation mIoU B16', color='red', marker='o')


plt.title('Mean IoU over Epochs')
plt.xlabel('Epochs')
plt.ylabel('mIoU')
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# Grafico IoU per classe
# classes = ['Class 1', 'Class 2', 'Class 3', 'Class 4', 'Class 5', 'Class 6', 'Class 7']
# plt.figure(figsize=(10, 5))
# plt.bar(classes, final_iou_B4, color='orange', alpha=0.7)
# plt.title('IoU per Class at Final Epoch B4')
# plt.ylabel('IoU')
# plt.xlabel('Classes')
# plt.xticks(rotation=45)
# plt.grid(axis='y', linestyle='--', alpha=0.7)
# plt.show()
