# %%
import matplotlib.pyplot as plt
import numpy as np

# Dati delle metriche
epochs = np.arange(1, 21)

loss_per_epoch_nst = [
    0.3871, 0.3616, 0.3377, 0.3287, 0.3208, 0.3140, 0.3053, 0.3030, 
    0.3017, 0.3010, 0.2943, 0.2976, 0.3007, 0.3041, 0.2952, 0.2943, 
    0.2957, 0.2943, 0.2941, 0.2953
]


# mIoU
miou_nst = [
    0.1811, 0.1649, 0.1963, 0.2546, 0.2081, 0.2106, 0.1800, 0.1894, 0.2241, 
    0.1930, 0.1925, 0.1418, 0.2141, 0.1910, 0.2064, 0.2071, 0.2102, 0.1828, 
    0.2020, 0.2057
]

# IoU per classe
per_class_iou = {
    "Background": [
        0.4006, 0.1987, 0.4431, 0.4453, 0.3917, 0.4154, 0.3617, 0.3653, 0.4471,
        0.3955, 0.3611, 0.3423, 0.3942, 0.4279, 0.4156, 0.3934, 0.4223, 0.3193, 
        0.4006, 0.4142
    ],
    "Building": [
        0.1852, 0.0735, 0.2895, 0.3061, 0.0976, 0.1502, 0.1199, 0.1211, 0.1800,
        0.1795, 0.1169, 0.2802, 0.1480, 0.2038, 0.1845, 0.1513, 0.1621, 0.1033, 
        0.1404, 0.1620
    ],
    "Road": [
        0.1516, 0.2426, 0.1315, 0.2511, 0.1954, 0.2227, 0.1909, 0.2461, 0.2619,
        0.2340, 0.2335, 0.1810, 0.2530, 0.2147, 0.2427, 0.2431, 0.2447, 0.2354, 
        0.2084, 0.2055
    ],
    "Water": [
        0.4100, 0.3839, 0.3719, 0.4815, 0.4538, 0.4416, 0.3780, 0.4078, 0.4581,
        0.3321, 0.4520, 0.1222, 0.4232, 0.3736, 0.3830, 0.4059, 0.4461, 0.4219, 
        0.3982, 0.4265
    ],
    "Barren": [
        0.0561, 0.0985, 0.0642, 0.0765, 0.1226, 0.0737, 0.1022, 0.0649, 0.0582,
        0.0725, 0.0763, 0.0369, 0.0784, 0.0354, 0.0696, 0.0735, 0.0755, 0.0647, 
        0.0908, 0.0764
    ],
    "Forest": [
        0.0199, 0.0147, 0.0234, 0.1156, 0.0209, 0.0522, 0.0134, 0.0413, 0.0552,
        0.0349, 0.0326, 0.0201, 0.0478, 0.0284, 0.0427, 0.0713, 0.0363, 0.0473, 
        0.0503, 0.0440
    ],
    "Agricultural": [
        0.0442, 0.1422, 0.0502, 0.1059, 0.1743, 0.1182, 0.0934, 0.0789, 0.1080,
        0.1017, 0.0744, 0.0097, 0.1540, 0.0526, 0.1064, 0.1110, 0.0843, 0.0875, 
        0.1252, 0.1108
    ]
}

seg_loss_bisenet =          [0.5244, 0.4181, 0.3789, 0.3652, 0.3416, 0.3313, 0.3211, 0.3112, 0.3044, 0.3004, 0.3034, 0.2976, 0.2934, 0.2899, 0.2880, 0.2879, 0.2835, 0.2819, 0.2797, 0.2768]
adv_loss_bisenet  =         [0.0007, 0.0009, 0.0009, 0.0010, 0.0011, 0.0012, 0.0013, 0.0015, 0.0015, 0.0017, 0.0017, 0.0018, 0.0021, 0.0021]
disc_loss_bisenet  =        [1.3726, 1.3048, 1.2546, 1.2061, 1.1649, 1.1271, 1.0879, 1.0338, 1.0081, 0.9690, 0.9468, 0.9245, 0.8551, 0.8392, 0.8249, 0.7976, 0.7831, 0.7544, 0.7450, 0.7292]
        0.4006, 0.4143
    ],
    'Building': [
        0.1853, 0.0736, 0.2895, 0.3062, 0.0977, 0.1502, 0.1199, 0.1212, 0.1801,
        0.1795, 0.1170, 0.2803, 0.1480, 0.2039, 0.1845, 0.1513, 0.1622, 0.1034, 
        0.1405, 0.1621
    ],
    'Road': [
        0.1516, 0.2426, 0.1316, 0.2511, 0.1954, 0.2227, 0.1909, 0.2462, 0.2619, 
        0.2341, 0.2335, 0.1811, 0.2531, 0.2148, 0.2427, 0.2432, 0.2448, 0.2355, 
        0.2085, 0.2055
    ],
    'Water': [
        0.4100, 0.3840, 0.3720, 0.4815, 0.4539, 0.4417, 0.3781, 0.4079, 0.4581, 
        0.3321, 0.4520, 0.1222, 0.4232, 0.3736, 0.3831, 0.4059, 0.4266, 0.4219, 
        0.3983, 0.4266
    ],
    'Barren': [
        0.0562, 0.0986, 0.0643, 0.0766, 0.1226, 0.0737, 0.1023, 0.0650, 0.0582, 
        0.0726, 0.0764, 0.0369, 0.0785, 0.0354, 0.0696, 0.0736, 0.0755, 0.0647, 
        0.0908, 0.0764
    ],
    'Forest': [
        0.0200, 0.0148, 0.0235, 0.1157, 0.0210, 0.0523, 0.0134, 0.0413, 0.0552, 
        0.0350, 0.0327, 0.0201, 0.0478, 0.0285, 0.0428, 0.0714, 0.0363, 0.0473, 
        0.0503, 0.0441
    ],
    'Agricultural': [
        0.0442, 0.1423, 0.0503, 0.1060, 0.1743, 0.1183, 0.0935, 0.0790, 0.1081, 
        0.1018, 0.0744, 0.0097, 0.1541, 0.0527, 0.1064, 0.1111, 0.0844, 0.0876, 
        0.1252, 0.1108
    ]
}

seg_loss_stdc = [0.3715, 0.3408, 0.3252, 0.3124, 0.3124, 0.3060, 0.3032, 0.2994, 0.2996, 0.2972, 0.2975, 0.2968, 0.2971, 0.2972, 0.2981, 0.2963, 0.2957, 0.2955, 0.2960, 0.2936]
target_miou_stdc = [0.3152, 0.3390, 0.2810, 0.3410, 0.3269, 0.3007, 0.2872, 0.3013, 0.2960, 0.3165, 0.2817, 0.2948, 0.2806, 0.2765, 0.2832, 0.2770, 0.2799, 0.2702, 0.2742, 0.2704]



#Grafico Loss
plt.figure(figsize=(10, 6))
plt.plot(epochs, loss_per_epoch_nst,  label="Training Loss (NST)")
plt.plot(epochs, seg_loss_bisenet, label='Segmentation Loss (BISENET)')
plt.plot(epochs, seg_loss_linknet, label='Segmentation Loss (LINKNET)')
plt.plot(epochs, seg_loss_stdc, label='Segmentation Loss (STDC)')


plt.title("Training Loss Over Epochs", fontsize=16)
plt.xlabel("Epoch", fontsize=14)
plt.ylabel("Loss", fontsize=14)
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend(fontsize=12)
plt.show()

# Grafico mIoU
plt.figure(figsize=(10, 6))
plt.plot(epochs, miou_nst, label="Validation mIoU (NST)")
plt.plot(epochs, target_miou_bisenet, label='Target mIoU (BISENET)')
plt.plot(epochs, target_miou_linknet, label='Target mIoU (LINKNET)')
plt.plot(epochs, target_miou_stdc, label='Target mIoU (STDC)')


plt.title("Validation mIoU Over Epochs", fontsize=16)
plt.xlabel("Epoch", fontsize=14)
plt.ylabel("mIoU", fontsize=14)
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend(fontsize=12)
plt.show()




# Grafico IoU per classe
plt.figure(figsize=(12, 8))
for class_name, values in per_class_iou.items():
    plt.plot(epochs, values, marker='o', label=class_name)

plt.title("Per-Class IoU Over Epochs bisnet", fontsize=16)
plt.xlabel("Epoch", fontsize=14)
plt.ylabel("IoU", fontsize=14)
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend(fontsize=12, loc='upper left')
plt.show()




plt.figure(figsize=(12, 8))
for class_name, values in per_class_iou_linknet.items():
    plt.plot(epochs, values, marker='o', label=class_name)

plt.title("Per-Class IoU Over Epochs linknet", fontsize=16)
plt.xlabel("Epoch", fontsize=14)
plt.ylabel("IoU", fontsize=14)
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend(fontsize=12, loc='upper left')
plt.show()


plt.figure(figsize=(12, 8))
for class_name, values in per_class_iou_NST.items():
    plt.plot(epochs, values, marker='o', label=class_name)

plt.title("Per-Class IoU Over Epochs NST", fontsize=16)
plt.xlabel("Epoch", fontsize=14)
plt.ylabel("IoU", fontsize=14)
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend(fontsize=12, loc='upper left')
plt.show()

# %%
#bisenet

# plt.figure(figsize=(8, 8))
# # plt.plot(epochs, loss_per_epoch_nst, marker='o', label="Training Loss (NST)")

# # plt.plot(epochs, seg_loss_linknet, label='Segmentation Loss (LINKNET)', marker='o')
# # plt.plot(epochs, seg_loss_stdc, label='Segmentation Loss (STDC)', marker='o')


# plt.title("Training Loss Over Epochs", fontsize=16)
# plt.xlabel("Epoch", fontsize=14)
# plt.ylabel("Loss", fontsize=14)
# plt.grid(True, linestyle='--', alpha=0.6)
# plt.legend(fontsize=12)
# plt.show()

# # Grafico mIoU
# plt.figure(figsize=(8, 8))
# # plt.plot(epochs, miou_nst, marker='o', label="Validation mIoU (NST)")

# # plt.plot(epochs, target_miou_linknet, label='Target mIoU (LINKNET)', marker='^')
# # plt.plot(epochs, target_miou_stdc, label='Target mIoU (STDC)', marker='^')


# plt.title("Validation mIoU Over Epochs", fontsize=16)
# plt.xlabel("Epoch", fontsize=14)
# plt.ylabel("mIoU", fontsize=14)
# plt.grid(True, linestyle='--', alpha=0.6)
# plt.legend(fontsize=12)
# plt.show()



import matplotlib.pyplot as plt

# Dati da estrarre dal log
epochs = list(range(1, 21))  # 20 epoche

# Valori estratti dal log
val_miou_stdc = [0.2812, 0.2633, 0.2547, 0.3140, 0.2961, 0.2979, 0.2907, 0.2902, 0.2903, 0.3131, 0.2829, 0.3031, 0.2885, 0.2905, 0.2967, 0.2910, 0.2979, 0.2908, 0.2910, 0.2932]
target_miou_stdc = [0.3152, 0.3390, 0.2810, 0.3410, 0.3269, 0.3007, 0.2872, 0.3013, 0.2960, 0.3165, 0.2817, 0.2948, 0.2806, 0.2765, 0.2832, 0.2770, 0.2799, 0.2702, 0.2742, 0.2704]
adv_loss_stdc = [0.0011, 0.0012, 0.0013, 0.0014, 0.0014, 0.0015, 0.0015, 0.0016, 0.0017, 0.0018, 0.0019, 0.0019, 0.0020, 0.0020, 0.0021, 0.0022, 0.0022, 0.0024, 0.0024, 0.0024]
disc_loss_stdc = [1.1712, 1.1314, 1.0858, 1.0535, 1.0454, 1.0084, 1.0117, 0.9611, 0.9304, 0.9158, 0.8855, 0.8849, 0.8438, 0.8361, 0.8181, 0.7977, 0.7722, 0.7453, 0.7271, 0.7162]


# Creazione dei grafici
plt.figure(figsize=(8, 8))

# Grafico Loss
plt.subplot(2, 1, 1)

# plt.plot(epochs, seg_loss_bisenet, label='Segmentation Loss (BISENET)', color='red')
# plt.plot(epochs, seg_loss_linknet, label='Segmentation Loss (LINKNET)', color='red')
plt.plot(epochs, seg_loss_stdc, label='Segmentation Loss (STDC)', color='red')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss')
plt.legend()
plt.grid(True)

# Grafico mIoU
plt.subplot(2, 1, 2)
# plt.plot(epochs, target_miou_bisenet, label='Target mIoU (BISENET)',  color='green')
# plt.plot(epochs, target_miou_linknet, label='Target mIoU (LINKNET)', color='green')
plt.plot(epochs, target_miou_stdc, label='Target mIoU (STDC)', color='green')
plt.plot(epochs,val_miou_stdc, label='Validation mIoU (STDC)', color='blue')

plt.xlabel('Epochs')
plt.ylabel('mIoU')
plt.title('Validation mIoU')
plt.legend()
plt.grid(True)

# Mostrare i grafici
plt.tight_layout()
plt.show()
