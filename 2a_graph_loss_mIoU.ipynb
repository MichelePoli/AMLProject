# %%
import matplotlib.pyplot as plt

# Data extracted from the log
epochs = list(range(1, 21))
loss_values = [
    1.3771, 1.2651, 0.9449, 0.8693, 0.8386, 0.7800, 0.7515, 0.6991, 
    0.6538, 0.6386, 0.5917, 0.5288, 0.5018, 0.5643, 0.4927, 0.4470, 
    0.4408, 0.5086, 0.4214, 0.4091
]
miou_values = [
    0.3954, 0.3668, 0.4069, 0.2915, 0.3206, 0.3205, 0.3291, 0.3177, 
    0.3410, 0.3173, 0.3092, 0.3031, 0.2616, 0.2987, 0.2524, 0.2698, 
    0.2816, 0.2541, 0.2880, 0.2761
]

# Create the plots
fig, axs = plt.subplots(2, 1, figsize=(10, 10))

# Loss plot
axs[0].plot(epochs, loss_values, marker='o', label="Loss", color='blue')
axs[0].set_title("Loss per Epoch")
axs[0].set_xlabel("Epoch")
axs[0].set_ylabel("Loss")
axs[0].grid(True)
axs[0].legend()

# mIoU plot
axs[1].plot(epochs, miou_values, marker='o', label="mIoU", color='green')
axs[1].set_title("mIoU per Epoch")
axs[1].set_xlabel("Epoch")
axs[1].set_ylabel("mIoU")
axs[1].grid(True)
axs[1].legend()

# Adjust layout and show
plt.tight_layout()
plt.show()
